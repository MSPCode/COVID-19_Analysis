# %% [markdown]
# # Week 1 - Exercise

# %% [markdown]
# # Coursera Capstone Project
#
# #### This project will use the foursquare API to explore and find the new apartment location

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# # Week 3 - Exercise

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from beautifulsoup4) (1.7.1)

# %%
import requests
from bs4 import BeautifulSoup

# %%
# Getting Wikipedia HTML content
req = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")

# %%
#Create a soup
soup = BeautifulSoup(req.text, 'lxml')

# %%
#Extract table body
table_body = soup.find('div', {'class': 'mw-parser-output'}).find('table').find('tbody')

# %%
#Extract all of the table rows and columns
table_lines =table_body.findAll('td')

# %%
#Extracting the postal code, borough and neighborhoods data from the soup
lst =[]
for i, element in enumerate(table_lines):
    span = table_lines[i].find('span')
    if span.text != 'Not assigned':
        postcode = element.find('b').text
        neighborhoods = element.findAll('a')
        areas = []
        for i, link in enumerate(neighborhoods):
                if i == 0:
                    borough = link.text
                    
                else:
                    areas.append(link.text)
            
        lst.append({
            'Postalcode': postcode,
            'Borough': borough,
            'Neighborhood': ','.join(areas)})

# %%
#Convert output to the dataframe
df = pd.DataFrame(lst)

# %%
#Restructure the format
df_copy = df[['Postalcode', 'Borough', 'Neighborhood']]
df_copy
# Out:
#     Postalcode              Borough  \
# 0          M3A           North York
# 1          M4A           North York
# 2          M5A     Downtown Toronto
# 3          M6A           North York
# 4          M7A     Downtown Toronto
# 5          M9A            Etobicoke
# 6          M1B          Scarborough
# 7          M3B           North York
# 8          M4B            East York
# 9          M5B     Downtown Toronto
# 10         M6B           North York
# 11         M9B            Etobicoke
# 12         M1C          Scarborough
# 13         M3C           North York
# 14         M4C            East York
# 15         M5C     Downtown Toronto
# 16         M6C                 York
# 17         M9C            Etobicoke
# 18         M1E          Scarborough
# 19         M4E          The Beaches
# 20         M5E     Downtown Toronto
# 21         M6E                 York
# 22         M1G          Scarborough
# 23         M4G            East York
# 24         M5G     Downtown Toronto
# 25         M6G     Downtown Toronto
# 26         M1H          Scarborough
# 27         M2H           North York
# 28         M3H           North York
# 29         M4H            East York
# ..         ...                  ...
# 73         M4R        North Toronto
# 74         M5R            The Annex
# 75         M6R             Parkdale
# 76         M7R          Mississauga
# 77         M9R            Etobicoke
# 78         M1S          Scarborough
# 79         M4S           Davisville
# 80         M5S     Downtown Toronto
# 81         M6S            Runnymede
# 82         M1T          Scarborough
# 83         M4T           Moore Park
# 84         M5T     Downtown Toronto
# 85         M1V          Scarborough
# 86         M4V           Summerhill
# 87         M5V     Downtown Toronto
# 88         M8V            Etobicoke
# 89         M9V            Etobicoke
# 90         M1W          Scarborough
# 91         M4W     Downtown Toronto
# 92         M5W     Downtown Toronto
# 93         M8W            Etobicoke
# 94         M9W            Etobicoke
# 95         M1X          Scarborough
# 96         M4X     Downtown Toronto
# 97         M5X     Downtown Toronto
# 98         M8X            Etobicoke
# 99         M4Y     Downtown Toronto
# 100        M7Y  Business reply mail
# 101        M8Y            Etobicoke
# 102        M8Z            Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                             Regent Park,Harbourfront
# 3                      Lawrence Manor,Lawrence Heights
# 4           Queen's Park,Ontario Provincial Government
# 5                                     Islington Avenue
# 6                                        Malvern,Rouge
# 7                                            Don Mills
# 8                       Parkview Hill,Woodbine Gardens
# 9                              Garden District,Ryerson
# 10
# 11   West Deane Park,Princess Gardens,Martin Grove,...
# 12                Rouge Hill,Port Union,Highland Creek
# 13                           Don Mills,Flemingdon Park
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17                                       Markland Wood
# 18                     Guildwood,Morningside,West Hill
# 19
# 20
# 21                                 Caledonia-Fairbanks
# 22                                              Woburn
# 23                                             Leaside
# 24                                          Bay Street
# 25
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28             Bathurst Manor,Wilson Heights,Downsview
# 29                                    Thorncliffe Park
# ..                                                 ...
# 73
# 74                             North Midtown,Yorkville
# 75                                        Roncesvalles
# 76
# 77                                   Kingsview Village
# 78                                           Agincourt
# 79
# 80                               University of Toronto
# 81                                             Swansea
# 82                              Tam O'Shanter,Sullivan
# 83                                          Summerhill
# 84             Kensington Market,Chinatown,Grange Park
# 85         Milliken,Agincourt North,Steeles,L'Amoreaux
# 86          Rathnelly,South Hill,Forest Hill,Deer Park
# 87   CN Tower,King and Spadina,Railway Lands,Harbou...
# 88                                  New Toronto,Mimico
# 89   South Steeles,Silverstone,Jamestown,Mount Oliv...
# 90                                  Steeles,L'Amoreaux
# 91                                            Rosedale
# 92
# 93                               Alderwood,Long Branch
# 94   Clairville,Humberwood,Woodbine Downs,Rexdale,Elms
# 95                                         Upper Rouge
# 96                          St. James Town,Cabbagetown
# 97               First Canadian Place,Underground city
# 98                               The Kingsway,Old Mill
# 99                                Church and Wellesley
# 100
# 101  Old Mill,Sunnylea,Humber Bay,Mimico,The Queensway
# 102                               Mimico,The Queensway
#
# [103 rows x 3 columns]

# %%
#Replace blanks with NaN
df.replace(r'^\s*$', np.nan, regex=True, inplace = True)

# %%
#Fill neighborhood with borough if not assigned
df_copy.Neighborhood.fillna(df.Borough, inplace=True)

# %%
# The code was removed by Watson Studio for sharing.

# %%
df_copy.shape
# Out:
# (102, 3)

# %%
df_copy
# Out:
#     Postalcode              Borough  \
# 0          M3A           North York
# 1          M4A           North York
# 2          M5A     Downtown Toronto
# 3          M6A           North York
# 4          M7A     Downtown Toronto
# 5          M9A            Etobicoke
# 6          M1B          Scarborough
# 7          M3B           North York
# 8          M4B            East York
# 9          M5B     Downtown Toronto
# 10         M6B           North York
# 11         M9B            Etobicoke
# 12         M1C          Scarborough
# 13         M3C           North York
# 14         M4C            East York
# 15         M5C     Downtown Toronto
# 16         M6C                 York
# 17         M9C            Etobicoke
# 18         M1E          Scarborough
# 19         M4E          The Beaches
# 20         M5E     Downtown Toronto
# 21         M6E                 York
# 22         M1G          Scarborough
# 23         M4G            East York
# 24         M5G     Downtown Toronto
# 25         M6G     Downtown Toronto
# 26         M1H          Scarborough
# 27         M2H           North York
# 28         M3H           North York
# 29         M4H            East York
# ..         ...                  ...
# 72         M2R           North York
# 73         M4R        North Toronto
# 74         M5R            The Annex
# 75         M6R             Parkdale
# 76         M7R          Mississauga
# 77         M9R            Etobicoke
# 78         M1S          Scarborough
# 79         M4S           Davisville
# 80         M5S     Downtown Toronto
# 81         M6S            Runnymede
# 82         M1T          Scarborough
# 83         M4T           Moore Park
# 84         M5T     Downtown Toronto
# 85         M1V          Scarborough
# 86         M4V           Summerhill
# 87         M5V     Downtown Toronto
# 88         M8V            Etobicoke
# 89         M9V            Etobicoke
# 90         M1W          Scarborough
# 91         M4W     Downtown Toronto
# 92         M5W     Downtown Toronto
# 94         M9W            Etobicoke
# 95         M1X          Scarborough
# 96         M4X     Downtown Toronto
# 97         M5X     Downtown Toronto
# 98         M8X            Etobicoke
# 99         M4Y     Downtown Toronto
# 100        M7Y  Business reply mail
# 101        M8Y            Etobicoke
# 102        M8Z            Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                             Regent Park,Harbourfront
# 3                      Lawrence Manor,Lawrence Heights
# 4           Queen's Park,Ontario Provincial Government
# 5                                     Islington Avenue
# 6                                        Malvern,Rouge
# 7                                            Don Mills
# 8                       Parkview Hill,Woodbine Gardens
# 9                              Garden District,Ryerson
# 10
# 11   West Deane Park,Princess Gardens,Martin Grove,...
# 12                Rouge Hill,Port Union,Highland Creek
# 13                           Don Mills,Flemingdon Park
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17                                       Markland Wood
# 18                     Guildwood,Morningside,West Hill
# 19
# 20
# 21                                 Caledonia-Fairbanks
# 22                                              Woburn
# 23                                             Leaside
# 24                                          Bay Street
# 25
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28             Bathurst Manor,Wilson Heights,Downsview
# 29                                    Thorncliffe Park
# ..                                                 ...
# 72                                          Willowdale
# 73
# 74                             North Midtown,Yorkville
# 75                                        Roncesvalles
# 76
# 77                                   Kingsview Village
# 78                                           Agincourt
# 79
# 80                               University of Toronto
# 81                                             Swansea
# 82                              Tam O'Shanter,Sullivan
# 83                                          Summerhill
# 84             Kensington Market,Chinatown,Grange Park
# 85         Milliken,Agincourt North,Steeles,L'Amoreaux
# 86          Rathnelly,South Hill,Forest Hill,Deer Park
# 87   CN Tower,King and Spadina,Railway Lands,Harbou...
# 88                                  New Toronto,Mimico
# 89   South Steeles,Silverstone,Jamestown,Mount Oliv...
# 90                                  Steeles,L'Amoreaux
# 91                                            Rosedale
# 92
# 94   Clairville,Humberwood,Woodbine Downs,Rexdale,Elms
# 95                                         Upper Rouge
# 96                          St. James Town,Cabbagetown
# 97               First Canadian Place,Underground city
# 98                               The Kingsway,Old Mill
# 99                                Church and Wellesley
# 100
# 101  Old Mill,Sunnylea,Humber Bay,Mimico,The Queensway
# 102                               Mimico,The Queensway
#
# [102 rows x 3 columns]

# %% [markdown]
# # Geocoding Exercise

# %%
#unable to use geocoder so using alternative library
import pgeocode

def latitude(zipcode):
    nomi = pgeocode.Nominatim('ca')
    result = nomi.query_postal_code(zipcode)
    return result['latitude']

def longitude(zipcode):
    nomi = pgeocode.Nominatim('ca')
    result = nomi.query_postal_code(zipcode)
    return result['longitude']

# %%
#Get the latitude and longitude data using pgeocode
df_copy['Latitude'] = df_copy['Postalcode'].map(lambda x: latitude(x))
df_copy['Longitude'] = df_copy['Postalcode'].map(lambda x: longitude(x))

# %%
df_copy
# Out:
#     Postalcode              Borough  \
# 0          M3A           North York
# 1          M4A           North York
# 2          M5A     Downtown Toronto
# 3          M6A           North York
# 4          M7A     Downtown Toronto
# 5          M9A            Etobicoke
# 6          M1B          Scarborough
# 7          M3B           North York
# 8          M4B            East York
# 9          M5B     Downtown Toronto
# 10         M6B           North York
# 11         M9B            Etobicoke
# 12         M1C          Scarborough
# 13         M3C           North York
# 14         M4C            East York
# 15         M5C     Downtown Toronto
# 16         M6C                 York
# 17         M9C            Etobicoke
# 18         M1E          Scarborough
# 19         M4E          The Beaches
# 20         M5E     Downtown Toronto
# 21         M6E                 York
# 22         M1G          Scarborough
# 23         M4G            East York
# 24         M5G     Downtown Toronto
# 25         M6G     Downtown Toronto
# 26         M1H          Scarborough
# 27         M2H           North York
# 28         M3H           North York
# 29         M4H            East York
# ..         ...                  ...
# 72         M2R           North York
# 73         M4R        North Toronto
# 74         M5R            The Annex
# 75         M6R             Parkdale
# 76         M7R          Mississauga
# 77         M9R            Etobicoke
# 78         M1S          Scarborough
# 79         M4S           Davisville
# 80         M5S     Downtown Toronto
# 81         M6S            Runnymede
# 82         M1T          Scarborough
# 83         M4T           Moore Park
# 84         M5T     Downtown Toronto
# 85         M1V          Scarborough
# 86         M4V           Summerhill
# 87         M5V     Downtown Toronto
# 88         M8V            Etobicoke
# 89         M9V            Etobicoke
# 90         M1W          Scarborough
# 91         M4W     Downtown Toronto
# 92         M5W     Downtown Toronto
# 94         M9W            Etobicoke
# 95         M1X          Scarborough
# 96         M4X     Downtown Toronto
# 97         M5X     Downtown Toronto
# 98         M8X            Etobicoke
# 99         M4Y     Downtown Toronto
# 100        M7Y  Business reply mail
# 101        M8Y            Etobicoke
# 102        M8Z            Etobicoke
#
#                                           Neighborhood  Latitude  Longitude
# 0                                            Parkwoods   43.7545   -79.3300
# 1                                     Victoria Village   43.7276   -79.3148
# 2                             Regent Park,Harbourfront   43.6555   -79.3626
# 3                      Lawrence Manor,Lawrence Heights   43.7223   -79.4504
# 4           Queen's Park,Ontario Provincial Government   43.6641   -79.3889
# 5                                     Islington Avenue   43.6662   -79.5282
# 6                                        Malvern,Rouge   43.8113   -79.1930
# 7                                            Don Mills   43.7450   -79.3590
# 8                       Parkview Hill,Woodbine Gardens   43.7063   -79.3094
# 9                              Garden District,Ryerson   43.6572   -79.3783
# 10                                                       43.7081   -79.4479
# 11   West Deane Park,Princess Gardens,Martin Grove,...   43.6505   -79.5517
# 12                Rouge Hill,Port Union,Highland Creek   43.7878   -79.1564
# 13                           Don Mills,Flemingdon Park   43.7334   -79.3329
# 14                                    Woodbine Heights   43.6913   -79.3116
# 15                                      St. James Town   43.6513   -79.3756
# 16                                  Humewood-Cedarvale   43.6915   -79.4307
# 17                                       Markland Wood   43.6437   -79.5767
# 18                     Guildwood,Morningside,West Hill   43.7678   -79.1866
# 19                                                       43.6784   -79.2941
# 20                                                       43.6456   -79.3754
# 21                                 Caledonia-Fairbanks   43.6889   -79.4507
# 22                                              Woburn   43.7712   -79.2144
# 23                                             Leaside   43.7124   -79.3644
# 24                                          Bay Street   43.6564   -79.3860
# 25                                                       43.6683   -79.4205
# 26                                           Cedarbrae   43.7686   -79.2389
# 27                                   Hillcrest Village   43.8015   -79.3577
# 28             Bathurst Manor,Wilson Heights,Downsview   43.7535   -79.4472
# 29                                    Thorncliffe Park   43.7059   -79.3464
# ..                                                 ...       ...        ...
# 72                                          Willowdale   43.7786   -79.4450
# 73                                                       43.7143   -79.4065
# 74                             North Midtown,Yorkville   43.6736   -79.4035
# 75                                        Roncesvalles   43.6469   -79.4521
# 76                                                           NaN        NaN
# 77                                   Kingsview Village   43.6898   -79.5582
# 78                                           Agincourt   43.7946   -79.2644
# 79                                                       43.7020   -79.3853
# 80                               University of Toronto   43.6629   -79.3987
# 81                                             Swansea   43.6512   -79.4828
# 82                              Tam O'Shanter,Sullivan   43.7812   -79.3036
# 83                                          Summerhill   43.6899   -79.3853
# 84             Kensington Market,Chinatown,Grange Park   43.6541   -79.3978
# 85         Milliken,Agincourt North,Steeles,L'Amoreaux   43.8177   -79.2819
# 86          Rathnelly,South Hill,Forest Hill,Deer Park   43.6861   -79.4025
# 87   CN Tower,King and Spadina,Railway Lands,Harbou...   43.6404   -79.3995
# 88                                  New Toronto,Mimico   43.6075   -79.5013
# 89   South Steeles,Silverstone,Jamestown,Mount Oliv...   43.7432   -79.5876
# 90                                  Steeles,L'Amoreaux   43.8016   -79.3216
# 91                                            Rosedale   43.6827   -79.3730
# 92                                                       43.6437   -79.3787
# 94   Clairville,Humberwood,Woodbine Downs,Rexdale,Elms   43.7144   -79.5909
# 95                                         Upper Rouge   43.8340   -79.2069
# 96                          St. James Town,Cabbagetown   43.6684   -79.3689
# 97               First Canadian Place,Underground city   43.6492   -79.3823
# 98                               The Kingsway,Old Mill   43.6518   -79.5076
# 99                                Church and Wellesley   43.6656   -79.3830
# 100                                                      43.7804   -79.2505
# 101  Old Mill,Sunnylea,Humber Bay,Mimico,The Queensway   43.6325   -79.4939
# 102                               Mimico,The Queensway   43.6256   -79.5231
#
# [102 rows x 5 columns]

# %% [markdown]
# ###
